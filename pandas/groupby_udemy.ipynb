# %%
import pandas as pd
fortune = pd.read_csv("udemy_material/fortune1000.csv", index_col ="Rank")
sector = fortune.groupby("Sector")

# %%
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sector_industry = fortune.groupby(["Sector", "Industry"])

# %%
sector_industry.get_group(('Energy', 'Petroleum Refining'))
# Out:
#                                   Company  Sector            Industry  \
# Rank
# 2                             Exxon Mobil  Energy  Petroleum Refining
# 14                                Chevron  Energy  Petroleum Refining
# 30                            Phillips 66  Energy  Petroleum Refining
# 32                          Valero Energy  Energy  Petroleum Refining
# 42                     Marathon Petroleum  Energy  Petroleum Refining
# 98                                 Tesoro  Energy  Petroleum Refining
# 214                         HollyFrontier  Energy  Petroleum Refining
# 217                            PBF Energy  Energy  Petroleum Refining
# 289                      Western Refining  Energy  Petroleum Refining
# 394                                  Hess  Energy  Petroleum Refining
# 445                     Delek US Holdings  Energy  Petroleum Refining
# 569                       Alon USA Energy  Energy  Petroleum Refining
# ...

# %%
sector_industry.size()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                             20
# Apparel                     Apparel                                           15
# Business Services           Advertising, marketing                             2
#                             Diversified Outsourcing Services                  14
#                             Education                                          3
#                             Financial Data Services                           19
#                             Miscellaneous                                      3
#                             Temporary Help                                     5
#                             Waste Management                                   5
# Chemicals                   Chemicals                                         30
# Energy                      Energy                                            14
# ...

# %%
sector_industry['Revenue'].sum()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                             357940
# Apparel                     Apparel                                            95968
# Business Services           Advertising, marketing                             22748
#                             Diversified Outsourcing Services                   64829
#                             Education                                           7485
#                             Financial Data Services                           100778
#                             Miscellaneous                                      11185
#                             Temporary Help                                     34716
#                             Waste Management                                   30454
# Chemicals                   Chemicals                                         243897
# Energy                      Energy                                             67749
# ...

# %%
# agg takes a dict
sector_industry.agg({'Revenue': "mean", "Profits": "mean"})
# Out:
#                                                                                 Revenue  \
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                           17897.000000
# Apparel                    Apparel                                          6397.866667
# Business Services          Advertising, marketing                          11374.000000
#                            Diversified Outsourcing Services                 4630.642857
#                            Education                                        2495.000000
#                            Financial Data Services                          5304.105263
#                            Miscellaneous                                    3728.333333
#                            Temporary Help                                   6943.200000
#                            Waste Management                                 6090.800000
# ...

# %%
sector_industry.agg(["size", "sum", "mean"])
# Out:
#                                                                           Revenue  \
#                                                                              size
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                               20
# Apparel                    Apparel                                             15
# Business Services          Advertising, marketing                               2
#                            Diversified Outsourcing Services                    14
#                            Education                                            3
#                            Financial Data Services                             19
#                            Miscellaneous                                        3
#                            Temporary Help                                       5
#                            Waste Management                                     5
# ...

# %%
new_df = pd.DataFrame(columns=fortune.columns)
for sect, data in sector:
    highest_rev_comp_in_group = data.nlargest(1, "Revenue")
    new_df = new_df.append(highest_rev_comp_in_group)
new_df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
group_obj = fortune.groupby("Sector")

# %%
new_df = pd.DataFrame(columns=df.columns) # gives same col headings as original df
for group, data in group_obj:
    largest = data.nlargest(1, "Profits")
    new_df = new_df.append(largest)
new_df
# Out:
#                      Company                        Sector  \
# 45       United Technologies           Aerospace & Defense
# 91                      Nike                       Apparel
# 204                     Visa             Business Services
# 56              Dow Chemical                     Chemicals
# 2                Exxon Mobil                        Energy
# 301                   Lennar    Engineering & Construction
# 23         J.P. Morgan Chase                    Financials
# 7                 CVS Health          Food and Drug Stores
# 62                 Coca-Cola     Food, Beverages & Tobacco
# 86           Gilead Sciences                   Health Care
# 534    Caesars Entertainment  Hotels, Resturants & Leisure
# 34          Procter & Gamble            Household Products
# 93                        3M                   Industrials
# 616                      USG                     Materials
# 53                    Disney                         Media
# ...
