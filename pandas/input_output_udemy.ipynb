# %%
import pandas as pd
# read from url, save exporting daily
# Hover over 'export as csv' ctrl click and select Copy Link Address
# Looks like this
#'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD'
# In reality we only need up to csv argument
#'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv'

# %%
# I had to paste the following into terminal to download from urls...
# /Applications/Python\ 3.6/Install\ Certificates.command

url = 'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv'
names = pd.read_csv(url)

# %%
names.sort_values('Count',ascending=False)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 3505            2011    MALE            HISPANIC             JAYDEN    426
# 5430            2011    MALE            HISPANIC             JAYDEN    426
# 1504            2011    MALE            HISPANIC             JAYDEN    426
# 7393            2011    MALE            HISPANIC             JAYDEN    426
# 15965           2011    MALE            HISPANIC             JAYDEN    426
# 9385            2012    MALE            HISPANIC             JAYDEN    364
# 17912           2012    MALE            HISPANIC             JAYDEN    364
# 19915           2013    MALE            HISPANIC             Jayden    352
# 11402           2013    MALE            HISPANIC             Jayden    352
# 22              2011  FEMALE            HISPANIC           ISABELLA    331
# 20471           2014  FEMALE            HISPANIC           Isabella    331
# ...

# %% [markdown]
# pip3 install xlrd
#
# pip3 install openpyxl

# %%
# Make an ExcelWriter object, then add the df's to that object and export
pd.ExcelWriter()

# %%
a = pd.read_excel('/Users/danielhaggerty/Google Drive/run.xlsx')
type(a)
# Out:
# pandas.core.frame.DataFrame
